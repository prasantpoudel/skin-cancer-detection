# %% [markdown]
# # From Ham1000 first extracting all 7 classes of image

# %%
import pandas as pd
import os
import shutil

# %%
df=pd.read_csv("HAM10000_metadata.csv")

# %%
df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
df['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
data_dir=os.getcwd()+"/all_image"
dest_dir=os.getcwd()+"/reorganize"

# %%
data_dir=os.getcwd()+"/all_image"
data_dir
# Out:
# '/Users/prasantpoudel/Desktop/skin/ham/all_image'

# %%
label=df['dx'].unique().tolist()

# %%
label
# Out:
# ['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec']

# %%
label_images=[]

# %%
for i in label:
    os.mkdir(dest_dir+"/"+str(i))
    sample=df[df['dx']==i]['image_id']
    label_images.extend(sample)
    for id in label_images:
        shutil.copyfile((data_dir+"/"+id+".jpg"),(dest_dir + "/"+i + "/"+id+".jpg"))
    label_images=[]

# %%
label_images
# Out:
# []

# %%
sample=df[df['dx']==i]['image_id']
label_images.extend(sample)

# %%
label_images
# Out:
# ['ISIC_0029417',
#  'ISIC_0029915',
#  'ISIC_0029360',
#  'ISIC_0026152',
#  'ISIC_0029659',
#  'ISIC_0026575',
#  'ISIC_0030586',
#  'ISIC_0025178',
#  'ISIC_0028730',
#  'ISIC_0029041',
#  'ISIC_0031040',
#  'ISIC_0031929',
#  'ISIC_0032173',
#  'ISIC_0033456',
#  'ISIC_0030408',
#  'ISIC_0027795',
#  'ISIC_0024913',
#  'ISIC_0032329',
#  'ISIC_0031198',
#  'ISIC_0026872',
#  'ISIC_0031191',
#  'ISIC_0025948',
#  'ISIC_0030242',
#  'ISIC_0031119',
#  'ISIC_0024562',
#  'ISIC_0026362',
#  'ISIC_0030297',
#  'ISIC_0027084',
#  'ISIC_0030714',
#  'ISIC_0028158',
#  'ISIC_0028231',
#  'ISIC_0026411',
#  'ISIC_0029634',
#  'ISIC_0031918',
#  'ISIC_0030803',
#  'ISIC_0025831',
#  'ISIC_0027231',
#  'ISIC_0027719',
#  'ISIC_0024843',
#  'ISIC_0028381',
#  'ISIC_0030602',
#  'ISIC_0031874',
#  'ISIC_0032437',
#  'ISIC_0025069',
#  'ISIC_0027700',
#  'ISIC_0025411',
#  'ISIC_0025130',
#  'ISIC_0030076',
#  'ISIC_0028816',
#  'ISIC_0028232',
#  'ISIC_0029067',
#  'ISIC_0026927',
# ...
